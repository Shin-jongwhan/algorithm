# %% [markdown]
# ### 문제
# #### https://school.programmers.co.kr/learn/courses/30/lessons/42746
#
# ```txt
# 문제 설명
# 0 또는 양의 정수가 주어졌을 때, 정수를 이어 붙여 만들 수 있는 가장 큰 수를 알아내 주세요.
#
# 예를 들어, 주어진 정수가 [6, 10, 2]라면 [6102, 6210, 1062, 1026, 2610, 2106]를 만들 수 있고, 이중 가장 큰 수는 6210입니다.
#
# 0 또는 양의 정수가 담긴 배열 numbers가 매개변수로 주어질 때, 순서를 재배치하여 만들 수 있는 가장 큰 수를 문자열로 바꾸어 return 하도록 solution 함수를 작성해주세요.
#
# 제한 사항
# - numbers의 길이는 1 이상 100,000 이하입니다.
# - numbers의 원소는 0 이상 1,000 이하입니다.
# - 정답이 너무 클 수 있으니 문자열로 바꾸어 return 합니다.
#
# 입출력 예
# numbers	return
# [6, 10, 2]	"6210"
# [3, 30, 34, 5, 9]	"9534330"
#
# ```

# %% [markdown]
# ---
#
# ### 풀이
# ```txt
# 가장 큰 정수를 만들려면 자릿수가 큰 쪽에서 큰 수를 순서대로 가지고 있으면 된다.
# 문자열 정렬의 특성을 이용해야 한다.
# 1. 같은 길이를 가진 숫자 비교는 int 비교와 같다.
# 2. 다른 길이라면, 문자열 정렬은 prefix 비교로 prefix 쪽에서 먼저 큰 수가 나오면 정렬이 된다.
#
# 방법
# 1. numbers 각 원소를 str로 변경
# 2. 원소의 최대가 1000이므로 최대 4자리까지 맞춰야 한다. 그래서 1자리가 4자리가 되려면 * 4를 하면 4자리가 된다. 이 상태에서 정렬, reverse = True.
# 3. 2번의 정렬된 상태로 이어붙이면 답
#
# 시간복잡도 : 정렬 O(nlogn)
# ```

# %%
def solution(numbers):
    lsNums_str = [str(nNum) for nNum in numbers]

    # 최대 4자리(1000)이므로 4번 반복해서 충분히 비교 가능
    lsNums_str = sorted(lsNums_str, key=lambda sNum: (sNum * 4)[:16], reverse=True)

    sAnswer = "".join(lsNums_str)
    if sAnswer[0] == "0":
        return "0"
    return sAnswer
    

# 답 "6210"
numbers = [6, 10, 2]
result = solution(numbers)
print(result)

# 답 "9534330"
numbers = [3, 30, 34, 5, 9]
result = solution(numbers)
print(result)

numbers = [100000, 1, 2, 9, 998, 988, 0]
result = solution(numbers)
print(result)

numbers = [9, 7, 1, 20, 30]
result = solution(numbers)
print(result)

numbers = [100, 10]
result = solution(numbers)
print(result)
# Out:
# 6210
# 9534330
# 9998988211000000
# 9730201
# 10100

# %%
ls = [0,1,5,3,2]
print(sorted(ls, reverse = True))
print([int(i) for i in str(1000)])

ls += [1,2,3]
print(ls)

print(int("00000"))
# Out:
# [5, 3, 2, 1, 0]
# [1, 0, 0, 0]
# [0, 1, 5, 3, 2, 1, 2, 3]
# 0
