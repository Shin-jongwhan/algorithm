# %% [markdown]
# ### 문제
# #### https://school.programmers.co.kr/learn/courses/30/lessons/12950
#
# ```txt
# 문제 설명
# 행렬의 덧셈은 행과 열의 크기가 같은 두 행렬의 같은 행, 같은 열의 값을 서로 더한 결과가 됩니다. 2개의 행렬 arr1과 arr2를 입력받아, 행렬 덧셈의 결과를 반환하는 함수, solution을 완성해주세요.
#
# 제한 조건
# 행렬 arr1, arr2의 행과 열의 길이는 500을 넘지 않습니다.
# 입출력 예
# arr1	arr2	return
# [[1,2],[2,3]]	[[3,4],[5,6]]	[[4,6],[7,9]]
# [[1],[2]]	[[3],[4]]	[[4],[6]]
#
# ```

# %%
# 두 행렬의 행 i, 열 j 크기는 동일함
# i, j로 접근하여 더하기
# 리턴값은 동일한 형상.

# 시간복잡도 O(n * m)
# i = n
# j = m

def solution(arr1, arr2):
    answer = []
    for i in range(0, len(arr2)) : 
        answer.append([])
        for j in range(0, len(arr2[i])) : 
            answer[i].append(arr1[i][j] + arr2[i][j])
    return answer

arr1 = [[1,2],[2,3]]
arr2 = [[3,4],[5,6]]
result = solution(arr1, arr2)
print(result)

arr1 = [[1],[2]]
arr2 = [[3],[4]]
result = solution(arr1, arr2)
print(result)
# Out:
# [[4, 6], [7, 9]]
# [[4], [6]]

# %% [markdown]
# ```
# 테스트 1 〉	통과 (0.01ms, 9.08MB)
# 테스트 2 〉	통과 (0.11ms, 9.24MB)
# 테스트 3 〉	통과 (0.64ms, 9.27MB)
# 테스트 4 〉	통과 (0.16ms, 9.27MB)
# 테스트 5 〉	통과 (0.08ms, 9.35MB)
# 테스트 6 〉	통과 (0.16ms, 9.14MB)
# 테스트 7 〉	통과 (0.02ms, 9.19MB)
# 테스트 8 〉	통과 (0.10ms, 9.16MB)
# 테스트 9 〉	통과 (1.23ms, 10.1MB)
# 테스트 10 〉	통과 (1.03ms, 9.59MB)
# 테스트 11 〉	통과 (0.66ms, 9.4MB)
# 테스트 12 〉	통과 (0.74ms, 9.68MB)
# 테스트 13 〉	통과 (0.66ms, 9.59MB)
# 테스트 14 〉	통과 (0.79ms, 9.7MB)
# 테스트 15 〉	통과 (0.81ms, 9.53MB)
# 테스트 16 〉	통과 (1.87ms, 9.75MB)
# 테스트 17 〉	통과 (40.15ms, 21.9MB)
# ```
